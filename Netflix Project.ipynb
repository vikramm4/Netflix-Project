# %% [markdown]
# ![Netflix-Logo.jpg](attachment:a54d832e-03c3-4bdf-9367-70d4d6f51170.jpg)

# %% [markdown]
# This Netflix Dataset has information about the TV shows and Movies available on Netflix till 2021.

# %%
import pandas as pd

# %%
# Try reading the file with a different encoding, such as 'ISO-8859-1' or 'latin1'
data = pd.read_csv(r'C:\Users\sai\Downloads\Netflix dataset.csv', encoding='ISO-8859-1')

# %%
d1
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7784        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                NaN                                            Nasty C
# 7787                NaN                         Adriano Zumbo, Rachel Khoo
# 7788           Sam Dunn                                                NaN
#
#                                                 Country        Release_Date  \
# 0                                                Brazil     August 14, 2020
# 1                                                Mexico   December 23, 2016
# 2                                             Singapore   December 20, 2018
# 3                                         United States   November 16, 2017
# 4                                         United States     January 1, 2020
# ...                                                 ...                 ...
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7785                                              India       March 2, 2019
# 7786                                                NaN  September 25, 2020
# 7787                                          Australia    October 31, 2020
# 7788              United Kingdom, Canada, United States       March 1, 2020
#
#      Rating   Duration                                               Type  \
# 0     TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     TV-MA     93 min                       Dramas, International Movies
# 2         R     78 min                Horror Movies, International Movies
# 3     PG-13     80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4     PG-13    123 min                                             Dramas
# ...     ...        ...                                                ...
# 7784  TV-MA     99 min                       Dramas, International Movies
# 7785  TV-14    111 min     Dramas, International Movies, Music & Musicals
# 7786  TV-MA     44 min  Documentaries, International Movies, Music & M...
# 7787  TV-PG   1 Season                 International TV Shows, Reality TV
# 7788  TV-MA     90 min                    Documentaries, Music & Musicals
#
#                                             Description
# 0     In a future where the elite inhabit an island ...
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# ...                                                 ...
# 7784  When Lebanon's Civil War deprives Zozo of his ...
# 7785  A scrappy but poor boy worms his way into a ty...
# 7786  In this documentary, South African rapper Nast...
# 7787  Dessert wizard Adriano Zumbo looks for the nex...
# 7788  This documentary delves into the mystique behi...
#
# [7789 rows x 11 columns]

# %%
data= d1

# %% [markdown]
# # head()

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# # tail()

# %%
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7785                                              India       March 2, 2019
# 7786                                                NaN  September 25, 2020
# 7787                                          Australia    October 31, 2020
# 7788              United Kingdom, Canada, United States       March 1, 2020
#
#      Rating  Duration                                               Type  \
# 7784  TV-MA    99 min                       Dramas, International Movies
# 7785  TV-14   111 min     Dramas, International Movies, Music & Musicals
# 7786  TV-MA    44 min  Documentaries, International Movies, Music & M...
# 7787  TV-PG  1 Season                 International TV Shows, Reality TV
# 7788  TV-MA    90 min                    Documentaries, Music & Musicals
#
#                                             Description
# 7784  When Lebanon's Civil War deprives Zozo of his ...
# 7785  A scrappy but poor boy worms his way into a ty...
# 7786  In this documentary, South African rapper Nast...
# 7787  Dessert wizard Adriano Zumbo looks for the nex...
# 7788  This documentary delves into the mystique behi...

# %% [markdown]
# # shape

# %%
data.shape       #to show the mo. of rows and columns
# Out:
# (7789, 11)

# %% [markdown]
# # size

# %%
data.size     # to show no. of total values(elements) in the dataset
# Out:
# 85679

# %% [markdown]
# # columns

# %%
data.columns      # to show the columns name
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# # dtypes

# %%
data.dtypes   # to show the data type of each column
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# # info()

# %%
data.info()    #to show indexes , columns, data types of each column , memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ## Task1. Is there any duplicate record in this dataset? if Yes, then remove the duplicate records.

# %% [markdown]
# ### duplicate()

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data[data.duplicated()]   #to check row wise and detect the duplicate rows
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace = True)        #to remove the duplicates rows permanently

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# ## Task2. Is there any null value Present in any column ? show with Heat-map.

# %% [markdown]
# ### Isnull()

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %%
data.isnull()     #to show where null value is present
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# 1      False     False  False        False
# 2      False     False  False        False
# 3      False     False  False        False
# 4      False     False  False        False
# ...      ...       ...    ...          ...
# 7784   False     False  False        False
# 7785   False     False  False        False
# 7786   False     False  False        False
# 7787   False     False  False        False
# 7788   False     False  False        False
#
# [7787 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# # seaborn library (HEAT-MAP)

# %%
import seaborn as sns   #to import seaborn library

# %%
sns.heatmap(data.isnull())     #using heat-map to show null values count
# Out:
# <Axes: >

# %%
#the white line are showing the null values in the column

# %% [markdown]
# ### Q1. For 'House of Cards' , what is the show id and who is te director of this show?

# %% [markdown]
# ## isin()

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %%
data[data['Title'].isin(['House of Cards'])]   #to show all records of a particular item in any column
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ## str.contains()

# %%
data[data['Title'].str.contains('House of Cards')]      # to show all records of a particular string in any column
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### Q2. In which year highest number of the TV shows & Movies were released ? show with bar graph.

# %% [markdown]
# #### dtypes

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ## to_datetime

# %%
data['Date_N'] = pd.to_datetime(data['Release_Date'])
# Out:
# C:\Users\sai\AppData\Local\Temp\ipykernel_8984\1147803333.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date_N'] = pd.to_datetime(data['Release_Date'])

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
# Delete a row by index (e.g., index 3)
data = data.drop(index=215)

# %%
data.shape
# Out:
# (7788, 11)

# %%
data['Date_N'].dt.year.value_counts()  #it counts the occurence of all individual years in date column.
# Out:
# Date_N
# 2019.0    2154
# 2020.0    2010
# 2018.0    1685
# 2017.0    1224
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %% [markdown]
# ### in 2019 the maximum no. of movies are released  = 2154

# %% [markdown]
# ## Bar Graph

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date_N'>

# %% [markdown]
# ### Q3. How many movies and tv shows are in the dataset ? show with bar graph .

# %% [markdown]
# ### groupby()

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data.groupby('Category').Category.count()   #to group all unique item of a column and show their count
# Out:
# Category
# Movie      5379
# TV Show    2409
# Name: Category, dtype: int64

# %% [markdown]
# ### countplot()

# %%
sns.countplot(data['Category'])  # to show the count of all unique values of any column in the form of bar graph
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %% [markdown]
# ### Q4. show all the movies that were released in year 2000.

# %% [markdown]
# ### creating new column

# %%
#data.head()
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data['year'] = data['Date_N'].dt.year     #to create new year column , it will consider only year

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %% [markdown]
# ## Filtering

# %%
data[(data['Category'] == 'Movie') & (data['year'] == 2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7761   s7761    Movie                                Zaki Chan
# 7782   s7782    Movie                                     Zoom
# 7783   s7783    Movie                                     Zozo
# 7785   s7785    Movie                        Zulu Man in Japan
# 7787   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# 28    Sabina Fedeli, Anna Migotto
# ...                           ...
# 7761                   Wael Ihsan
# 7782                 Peter Hewitt
# 7783                  Josef Fares
# 7785                          NaN
# 7787                     Sam Dunn
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 6     Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...
# 14    Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...
# 27                             Yoo Ah-in, Park Shin-hye
# 28                          Helen Mirren, Gengher Gatti
# ...                                                 ...
# 7761  Ahmed Helmy, Yasmin Abdulaziz, Hassan Hosny, H...
# 7782  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 7783  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785                                            Nasty C
# 7787                                                NaN
#
#                                                 Country Release_Date Rating  \
# 4                                         United States     1-Jan-20  PG-13
# 6                                                 Egypt     1-Jun-20  TV-MA
# 14                                        United States    19-Mar-20      R
# 27                                          South Korea     8-Sep-20  TV-MA
# 28                                                Italy     1-Jul-20  TV-14
# ...                                                 ...          ...    ...
# 7761                                              Egypt    19-May-20  TV-PG
# 7782                                      United States    11-Jan-20     PG
# 7783  Sweden, Czech Republic, United Kingdom, Denmar...    19-Oct-20  TV-MA
# 7785                                                NaN    25-Sep-20  TV-MA
# 7787              United Kingdom, Canada, United States     1-Mar-20  TV-MA
#
#      Duration                                               Type  \
# 4     123 min                                             Dramas
# 6      95 min                Horror Movies, International Movies
# 14     91 min    Independent Movies, Sci-Fi & Fantasy, Thrillers
# 27     99 min     Horror Movies, International Movies, Thrillers
# 28     95 min                Documentaries, International Movies
# ...       ...                                                ...
# 7761  109 min    Comedies, International Movies, Romantic Movies
# 7782   88 min                 Children & Family Movies, Comedies
# 7783   99 min                       Dramas, International Movies
# 7785   44 min  Documentaries, International Movies, Music & M...
# 7787   90 min                    Documentaries, Music & Musicals
#
#                                             Description     Date_N    year
# 4     A brilliant group of students become card-coun... 2020-01-01  2020.0
# 6     After an awful accident, a couple admitted to ... 2020-06-01  2020.0
# 14    Stranded when the Earth is suddenly destroyed ... 2020-03-19  2020.0
# 27    As a grisly virus rampages a city, a lone man ... 2020-09-08  2020.0
# 28    Through her diary, Anne Frank's story is retol... 2020-07-01  2020.0
# ...                                                 ...        ...     ...
# 7761  An unqualified young man has his work cut out ... 2020-05-19  2020.0
# 7782  Dragged from civilian life, a former superhero... 2020-01-11  2020.0
# 7783  When Lebanon's Civil War deprives Zozo of his ... 2020-10-19  2020.0
# 7785  In this documentary, South African rapper Nast... 2020-09-25  2020.0
# 7787  This documentary delves into the mystique behi... 2020-03-01  2020.0
#
# [1313 rows x 13 columns]

# %% [markdown]
# ### Q5. show only the titles of all tv shows released in india only.

# %% [markdown]
# ### FIltering

# %%
data[(data['Category']=='TV Show') & (data['Country']=='India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 339                           Agent Raghav
# 363                           Akbar Birbal
# 532                    Anjaan: Rural Myths
#                        ...
# 6248                  The Creative Indians
# 6399    The Golden Years with Javed Akhtar
# 6468                The House That Made Me
# 7293                            Typewriter
# 7704                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ### Q6. show top 10 directors, who gave the highest number of tv shows & movies to netflix?

# %% [markdown]
# ### value_counts()

# %%
data['Director'].value_counts().head(10)   #to see the top 10  directors
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %% [markdown]
# ## Q7. show all the records , where " category is movie and type is comedies" or " country is united kingdom".

# %% [markdown]
# ### Filtering(And, or operators)

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data[(data['Category']=='Movie')&(data['Type']=='Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7340   s7340    Movie         Undercover Brother 2            Leslie Small
# 7589   s7589    Movie            Where's the Money         Scott Zabielski
# 7622   s7622    Movie                    Wild Oats            Andy Tennant
# 7633   s7633    Movie                 Wine Country             Amy Poehler
# 7663   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# 33    Nesta Cooper, Kate Walsh, John Michael Higgins...
# 72    Zac Efron, Leslie Mann, Matthew Perry, Thomas ...
# 84    Miles Teller, Skylar Astin, Justin Chon, Sarah...
# 148   Mila Kunis, Kristen Bell, Kathryn Hahn, Susan ...
# 174   Will Forte, Domhnall Gleeson, Martin Mull, Joe...
# ...                                                 ...
# 7340  Michael Jai White, Vince Swann, Barry Bostwick...
# 7589  Andrew Bachelor, Kat Graham, Mike Epps, Terry ...
# 7622  Shirley MacLaine, Jessica Lange, Billy Connoll...
# 7633  Amy Poehler, Maya Rudolph, Ana Gasteyer, Rache...
# 7663  Sabrina Carpenter, Jordan Fisher, Liza Koshy, ...
#
#                      Country Release_Date Rating Duration      Type  \
# 33             United States     8-Sep-17  TV-14   99 min  Comedies
# 72             United States     1-Jan-21  PG-13  102 min  Comedies
# 84             United States    16-Apr-19      R   93 min  Comedies
# 148     United States, China    14-Feb-20      R  104 min  Comedies
# 174            United States    26-Jan-18  TV-MA  102 min  Comedies
# ...                      ...          ...    ...      ...       ...
# 7340           United States     5-Nov-19      R   85 min  Comedies
# 7589           United States    22-Jan-18      R   86 min  Comedies
# 7622  Germany, United States    13-May-17  PG-13   86 min  Comedies
# 7633           United States    10-May-19      R  104 min  Comedies
# 7663           United States     7-Aug-20  TV-14   94 min  Comedies
#
#                                             Description
# 33    When nerdy high schooler Dani finally attracts...
# 72    Nearing a midlife crisis, thirty-something Mik...
# 84    Jeff's straight-and-narrow life changes abrupt...
# 148   Stressed-out moms Amy, Carla and Kiki are back...
# 174   In a brief life full of triumph and failure, "...
# ...                                                 ...
# 7340  When a beloved secret agent falls deep into a ...
# 7589  Hunting for a stash of stolen money, a sharp-w...
# 7622  When insurance accidentally pays her millions,...
# 7633  When longtime friends meet up for a wine-soake...
# 7663  A brilliant but clumsy high school senior vows...
#
# [97 rows x 11 columns]

# %%
data[(data['Category']=='Movie')&(data['Type']=='Comedies') | (data['Country']=='United kingdom')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7340   s7340    Movie         Undercover Brother 2            Leslie Small
# 7589   s7589    Movie            Where's the Money         Scott Zabielski
# 7622   s7622    Movie                    Wild Oats            Andy Tennant
# 7633   s7633    Movie                 Wine Country             Amy Poehler
# 7663   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# 33    Nesta Cooper, Kate Walsh, John Michael Higgins...
# 72    Zac Efron, Leslie Mann, Matthew Perry, Thomas ...
# 84    Miles Teller, Skylar Astin, Justin Chon, Sarah...
# 148   Mila Kunis, Kristen Bell, Kathryn Hahn, Susan ...
# 174   Will Forte, Domhnall Gleeson, Martin Mull, Joe...
# ...                                                 ...
# 7340  Michael Jai White, Vince Swann, Barry Bostwick...
# 7589  Andrew Bachelor, Kat Graham, Mike Epps, Terry ...
# 7622  Shirley MacLaine, Jessica Lange, Billy Connoll...
# 7633  Amy Poehler, Maya Rudolph, Ana Gasteyer, Rache...
# 7663  Sabrina Carpenter, Jordan Fisher, Liza Koshy, ...
#
#                      Country Release_Date Rating Duration      Type  \
# 33             United States     8-Sep-17  TV-14   99 min  Comedies
# 72             United States     1-Jan-21  PG-13  102 min  Comedies
# 84             United States    16-Apr-19      R   93 min  Comedies
# 148     United States, China    14-Feb-20      R  104 min  Comedies
# 174            United States    26-Jan-18  TV-MA  102 min  Comedies
# ...                      ...          ...    ...      ...       ...
# 7340           United States     5-Nov-19      R   85 min  Comedies
# 7589           United States    22-Jan-18      R   86 min  Comedies
# 7622  Germany, United States    13-May-17  PG-13   86 min  Comedies
# 7633           United States    10-May-19      R  104 min  Comedies
# 7663           United States     7-Aug-20  TV-14   94 min  Comedies
#
#                                             Description
# 33    When nerdy high schooler Dani finally attracts...
# 72    Nearing a midlife crisis, thirty-something Mik...
# 84    Jeff's straight-and-narrow life changes abrupt...
# 148   Stressed-out moms Amy, Carla and Kiki are back...
# 174   In a brief life full of triumph and failure, "...
# ...                                                 ...
# 7340  When a beloved secret agent falls deep into a ...
# 7589  Hunting for a stash of stolen money, a sharp-w...
# 7622  When insurance accidentally pays her millions,...
# 7633  When longtime friends meet up for a wine-soake...
# 7663  A brilliant but clumsy high school senior vows...
#
# [97 rows x 11 columns]

# %% [markdown]
# ## Q8. In how many movies/shows, tom cruise was cast?

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# ### filtering

# %%
data[data['Cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# ## str.contails()

# %%
data[data['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data[data['Cast'].str.contains('Tom Cruise')]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4092, in DataFrame.__getitem__(self, key)
#    4089     return self.where(key)
#    4091 # Do we have a (boolean) 1d indexer?
# -> 4092 if com.is_bool_indexer(key):
#    4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\common.py:136, in is_bool_indexer(key)
#     132     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133     if lib.is_bool_array(key_array, skipna=True):
#     134         # Don't raise on e.g. ["A", "B", np.nan], see
#     135         #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 136         raise ValueError(na_msg)
#     137     return False
#     138 return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %% [markdown]
# ## creating new data-frame

# %%
data_new = data.dropna()    #it  drops the rows that contains all or any missing values.

# %%
data_new.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3859   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5070   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3859  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5070  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3859     1-Jan-20      R  189 min  Dramas, Independent Movies
# 5070     1-Jul-19      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 3859  Through chance, human action, past history and...
# 5070  A fast-talking yuppie is forced to slow down w...

# %% [markdown]
# ## Q9. what are the different ratings defined by netflix?

# %% [markdown]
# ### nunique()

# %%
data.Rating.nunique()
# Out:
# 14

# %% [markdown]
# ### unique()

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### Q 9.1. How many movies got the 'TV-14' rating in canada?

# %%
data[(data['Category']=='Movie')&(data['Rating']=='TV-14')].shape
# Out:
# (1272, 11)

# %%
data[(data['Category']=='Movie')&(data['Rating']=='TV-14') & (data['Country']=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 607     s609    Movie                               At First Light
# 1505   s1507    Movie                   Counterfeiting in Suburbia
# 3712   s3714    Movie                            Long Time Running
# 3955   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5335   s5336    Movie                   Sadie's Last Days on Earth
# 5392   s5393    Movie                                   Sardaar ji
# 6061   s6062    Movie                  The Accountant of Auschwitz
# 7024   s7024    Movie                         The Wrong Babysitter
# 7040   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# 607                              Jason Stone
# 1505                           Jason Bourque
# 3712  Jennifer Baichwal, Nicholas de Pencier
# 3955                     Jean-François Blais
# 5335                          Michael Seater
# 5392                            Rohit Jugraj
# 6061                        Matthew Shoychet
# 7024                         George Mendeluk
# 7040                  Ellen Page, Ian Daniel
#
#                                                    Cast Country Release_Date  \
# 30                                                  NaN  Canada     5-Feb-20
# 34    Jake Short, Sarah Fisher, Booboo Stewart, Dann...  Canada    10-Apr-19
# 607   Stefanie Scott, Theodore Pellerin, Percy Hynes...  Canada    27-Dec-18
# 1505  Sarah Butler, Larissa Albuquerque, Kayla Walla...  Canada     1-Jul-18
# 3712  Gord Downie, Paul Langlois, Gord Sinclair, Rob...  Canada    12-Nov-17
# 3955                                       Martin Matte  Canada    14-Oct-19
# 5335  Morgan Taylor Campbell, Clark Backo, Ricardo H...  Canada    22-Aug-17
# 5392  Diljit Dosanjh, Neeru Bajwa, Mandy Takhar, Jas...  Canada     1-Dec-17
# 6061                                                NaN  Canada     1-Jul-19
# 7024  Daphne Zuniga, Seann Gallagher, Lisa Marie Car...  Canada    18-Jun-19
# 7040                                         Ellen Page  Canada    27-Mar-20
#
#      Rating Duration                                               Type  \
# 30    TV-14   90 min                Documentaries, International Movies
# 34    TV-14  105 min                          Comedies, Romantic Movies
# 607   TV-14   91 min                           Dramas, Sci-Fi & Fantasy
# 1505  TV-14   88 min                                  Dramas, Thrillers
# 3712  TV-14   96 min  Documentaries, International Movies, Music & M...
# 3955  TV-14   62 min                                    Stand-Up Comedy
# 5335  TV-14   94 min                         Comedies, Sci-Fi & Fantasy
# 5392  TV-14  140 min   Comedies, International Movies, Music & Musicals
# 6061  TV-14   78 min                Documentaries, International Movies
# 7024  TV-14   89 min                                          Thrillers
# 7040  TV-14   72 min                Documentaries, International Movies
#
#                                             Description
# 30    This pawesome documentary explores how our fel...
# 34    A teenage hacker with a huge nose helps a cool...
# 607   After mysterious lights imbue her with extraor...
# 1505  Two teenagers print counterfeit money in their...
# 3712  This documentary follows the 2016 tour of belo...
# 3955  Quebecois comedy star Martin Matte serves up e...
# 5335  High schooler Sadie Mitchell believes the worl...
# 5392  When a palatial wedding venue turns out to be ...
# 6061  Decades after WWII, a former SS officer stands...
# 7024  A widow searches for her missing teenage daugh...
# 7040  This documentary spotlights the struggle of mi...

# %%
data[(data['Category']=='Movie')&(data['Rating']=='TV-14') & (data['Country']=='Canada')].shape
# Out:
# (11, 11)

# %% [markdown]
# ### Q 9.2. How many TV shows got the 'R' rating. after year 2018?

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %%
data[(data['Category']=='TV Show') & (data['Rating']=='R')]
# Out:
#      Show_Id Category                                Title           Director  \
# 4496   s4498  TV Show                                Nobel                NaN
# 6436   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 4496  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway    10-Dec-16
# 6436  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN    25-Apr-19
#
#      Rating  Duration                                             Type  \
# 4496      R  1 Season  International TV Shows, TV Dramas, TV Thrillers
# 6436      R  1 Season                                         TV Shows
#
#                                             Description
# 4496  A series of incidents in Afghanistan set compl...
# 6436  Trapped at a stagecoach stop as a storm rages ...

# %%
data[(data['Category']=='TV Show') & (data['Rating']=='R') & (data['year'] > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6436   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6436  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN    25-Apr-19
#
#      Rating  Duration      Type  \
# 6436      R  1 Season  TV Shows
#
#                                             Description     Date_N    year
# 6436  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
data.info
# Out:
# <bound method DataFrame.info of      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7783   s7783    Movie                                     Zozo
# 7784   s7784    Movie                                   Zubaan
# 7785   s7785    Movie                        Zulu Man in Japan
# 7786   s7786  TV Show                    Zumbo's Just Desserts
# 7787   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7783        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7784        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7785                NaN                                            Nasty C
# 7786                NaN                         Adriano Zumbo, Rachel Khoo
# 7787           Sam Dunn                                                NaN
#
#                                                 Country Release_Date Rating  \
# 0                                                Brazil    14-Aug-20  TV-MA
# 1                                                Mexico    23-Dec-16  TV-MA
# 2                                             Singapore    20-Dec-18      R
# 3                                         United States    16-Nov-17  PG-13
# 4                                         United States     1-Jan-20  PG-13
# ...                                                 ...          ...    ...
# 7783  Sweden, Czech Republic, United Kingdom, Denmar...    19-Oct-20  TV-MA
# 7784                                              India     2-Mar-19  TV-14
# 7785                                                NaN    25-Sep-20  TV-MA
# 7786                                          Australia    31-Oct-20  TV-PG
# 7787              United Kingdom, Canada, United States     1-Mar-20  TV-MA
#
#        Duration                                               Type  \
# 0     4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1        93 min                       Dramas, International Movies
# 2        78 min                Horror Movies, International Movies
# 3        80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4       123 min                                             Dramas
# ...         ...                                                ...
# 7783     99 min                       Dramas, International Movies
# 7784    111 min     Dramas, International Movies, Music & Musicals
# 7785     44 min  Documentaries, International Movies, Music & M...
# 7786   1 Season                 International TV Shows, Reality TV
# 7787     90 min                    Documentaries, Music & Musicals
#
#                                             Description
# 0     In a future where the elite inhabit an island ...
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# ...                                                 ...
# 7783  When Lebanon's Civil War deprives Zozo of his ...
# 7784  A scrappy but poor boy worms his way into a ty...
# 7785  In this documentary, South African rapper Nast...
# 7786  Dessert wizard Adriano Zumbo looks for the nex...
# 7787  This documentary delves into the mystique behi...
#
# [7788 rows x 11 columns]>

# %% [markdown]
# ### Q 10. what is the maximum durationof a movie/show on netflix?

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
#        '26 min', '156 min', '30 min', '57 min', '150 min', '133 min',
#        '115 min', '154 min', '127 min', '146 min', '136 min', '88 min',
#        '131 min', '24 min', '112 min', '74 min', '63 min', '38 min',
#        '25 min', '174 min', '60 min', '153 min', '158 min', '151 min',
#        '162 min', '54 min', '51 min', '69 min', '64 min', '147 min',
#        '42 min', '79 min', '5 Seasons', '40 min', '45 min', '172 min',
#        '10 min', '163 min', '9 Seasons', '55 min', '72 min', '61 min',
#        '71 min', '160 min', '171 min', '48 min', '139 min', '157 min',
#        '15 min', '65 min', '134 min', '161 min', '62 min', '8 Seasons',
#        '186 min', '49 min', '73 min', '58 min', '165 min', '166 min',
#        '138 min', '159 min', '141 min', '132 min', '52 min', '67 min',
#        '34 min', '66 min', '312 min', '180 min', '47 min', '6 Seasons',
#        '155 min', '14 min', '177 min', '11 min', '9 min', '46 min',
#        '145 min', '11 Seasons', '7 Seasons', '13 Seasons', '8 min',
#        '12 min', '12 Seasons', '10 Seasons', '43 min', '50 min', '23 min',
#        '185 min', '200 min', '169 min', '27 min', '170 min', '196 min',
#        '33 min', '181 min', '204 min', '32 min', '35 min', '167 min',
#        '16 Seasons', '179 min', '193 min', '13 min', '214 min', '17 min',
#        '173 min', '192 min', '209 min', '187 min', '41 min', '182 min',
#        '224 min', '233 min', '189 min', '152 min', '19 min', '15 Seasons',
#        '208 min', '237 min', '31 min', '178 min', '230 min', '194 min',
#        '228 min', '195 min', '3 min', '16 min', '5 min', '18 min',
#        '205 min', '190 min', '36 min', '201 min', '253 min', '203 min',
#        '191 min'], dtype=object)

# %% [markdown]
# ### str.split()

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[['Minutes','Unit']]=data['Duration'].str.split(' ',expand =True)

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %% [markdown]
# ### max()

# %%
data['Minutes'].max()
# Out:
# '99'

# %%
data['Minutes'].min()
# Out:
# '1'

# %% [markdown]
# ### Q 11. which individual country has the highest no. of TV shows?

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          Description     Date_N    year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0
# 3  In a postapocalyptic world, rag-doll robots hi... 2017-11-16  2017.0
# 4  A brilliant group of students become card-coun... 2020-01-01  2020.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min
# 2      78      min
# 3      80      min
# 4     123      min

# %%
data_tvshow=data[data['Category']=='TV Show']

# %%
data_tvshow.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 5  Erdal Besikçioglu, Yasemin Allen, Melis Birkan...  Turkey     1-Jul-17
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description     Date_N    year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0
#
#   Minutes     Unit
# 0       4  Seasons
# 5       1   Season

# %%
data_tvshow.Country.value_counts()
# Out:
# Country
# United States                                    705
# United Kingdom                                   204
# Japan                                            157
# South Korea                                      146
# India                                             71
#                                                 ...
# United Kingdom, Ireland, United States             1
# United Kingdom, Spain                              1
# Italy, United States                               1
# Japan, Canada                                      1
# United States, France, South Korea, Indonesia      1
# Name: count, Length: 183, dtype: int64

# %%
data_tvshow.Country.value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %% [markdown]
# ### Q 12. How can we sort the dataset by year?

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
data.sort_values(by='year').head(2)
# Out:
#      Show_Id Category                 Title              Director  \
# 1764   s1766  TV Show       Dinner for Five                   NaN
# 7114   s7114    Movie  To and From New York  Sorin Dan Mihalcescu
#
#                                                    Cast        Country  \
# 1764                                                NaN  United States
# 7114  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
#
#      Release_Date Rating  Duration                                   Type  \
# 1764     4-Feb-08  TV-MA  1 Season           Stand-Up Comedy & Talk Shows
# 7114     1-Jan-08  TV-MA    81 min  Dramas, Independent Movies, Thrillers
#
#                                             Description     Date_N    year  \
# 1764  In each episode, four celebrities join host Jo... 2008-02-04  2008.0
# 7114  While covering a story in New York City, a Sea... 2008-01-01  2008.0
#
#      Minutes    Unit
# 1764       1  Season
# 7114      81     min

# %%
data.sort_values(by='year', ascending= False).head(2)
# Out:
#      Show_Id Category                 Title              Director  \
# 4268   s4270    Movie                   Mud          Jeff Nichols
# 6478   s6478  TV Show  The Idhun Chronicles  Maite Ruiz De Austri
#
#                                                    Cast        Country  \
# 4268  Matthew McConaughey, Reese Witherspoon, Tye Sh...  United States
# 6478  Michelle Jenner, Itzan Escamilla, Sergio Mur, ...          Spain
#
#      Release_Date Rating   Duration  \
# 4268     1-Jan-21  PG-13    131 min
# 6478     8-Jan-21  TV-14  2 Seasons
#
#                                                    Type  \
# 4268                         Dramas, Independent Movies
# 6478  Anime Series, International TV Shows, Spanish-...
#
#                                             Description     Date_N    year  \
# 4268  Two Mississippi teens meet peculiar drifter Mu... 2021-01-01  2021.0
# 6478  A boy suddenly orphaned fights his parents' ki... 2021-01-08  2021.0
#
#      Minutes     Unit
# 4268     131      min
# 6478       2  Seasons
